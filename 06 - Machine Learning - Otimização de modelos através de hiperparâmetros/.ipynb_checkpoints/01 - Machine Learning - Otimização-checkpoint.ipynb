# %%
import pandas as pd
import numpy as np

# %%
uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"
dados = pd.read_csv(uri).drop(columns=["Unnamed: 0"], axis=1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               18  35085.22134
# 1   40557.96        1               20  12622.05362
# 2   89627.50        0               12  11440.79806
# 3   95276.14        0                3  43167.32682
# 4  117384.68        1                4  12770.11290

# %%
# situação horrível de "azar" onde as classes estão ordenadas por padrão

dados_azar = dados.sort_values("vendido", ascending=True)
x_azar = dados_azar[["preco", "idade_do_modelo","km_por_ano"]]
y_azar = dados_azar["vendido"]
dados_azar.head()
# Out:
#          preco  vendido  idade_do_modelo   km_por_ano
# 4999  74023.29        0               12  24812.80412
# 5322  84843.49        0               13  23095.63834
# 5319  83100.27        0               19  36240.72746
# 5316  87932.13        0               16  32249.56426
# 5315  77937.01        0               15  28414.50704

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier

SEED = 301
np.random.seed(SEED)

modelo = DummyClassifier()
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com dummy stratified, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com dummy stratified, 10 = [49.79, 53.45]

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
# gerando dados elatorios de modelo de carro para simulacao de agrupamento ao usar nosso estimador

np.random.seed(SEED)
dados['modelo'] = dados.idade_do_modelo + np.random.randint(-2, 3, size=10000)
dados.modelo = dados.modelo + abs(dados.modelo.min()) + 1
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano  modelo
# 0   30941.02        1               18  35085.22134      18
# 1   40557.96        1               20  12622.05362      24
# 2   89627.50        0               12  11440.79806      14
# 3   95276.14        0                3  43167.32682       6
# 4  117384.68        1                4  12770.11290       5

# %%
def imprime_resultados(results):
  media = results['test_score'].mean() * 100
  desvio = results['test_score'].std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
# GroupKFold para analisar como o modelo se comporta com novos grupos

from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.67, 77.90]

# %%
# GroupKFold em um pipeline com StandardScaler e SVC

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.exceptions import DataConversionWarning
import warnings

warnings.simplefilter(action='ignore', category=DataConversionWarning)


SEED = 301
np.random.seed(SEED)

scaler = StandardScaler()
modelo = SVC()

pipeline = Pipeline([('transformacao',scaler), ('estimador',modelo)])

cv = GroupKFold(n_splits = 10)
results = cross_validate(pipeline, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.68
# Intervalo [74.28, 79.08]

# %% [markdown]
# ## Árvore com 2 níveis

# %%
from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.67, 77.90]

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar,y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None,filled=True,rounded=True,
                   class_names=["não","sim"],
                   feature_names = features)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ## Árvore com 3 níveis

# %%
from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=3)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 78.67
# Intervalo [76.40, 80.94]

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar,y_azar)
features = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None,filled=True,rounded=True,
                   class_names=["não","sim"],
                   feature_names = features)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ## Árvore com 10 níveis

# %%
from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=10)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 77.19
# Intervalo [75.26, 79.13]

# %% [markdown]
# Ficou pior que a de 3 níveis.

# %% [markdown]
# ## Explorando hiperparâmetros em uma dimensão (max_depth)

# %%
def roda_arvore_de_decisao(max_depth):
    SEED = 301
    np.random.seed(SEED)

    cv = GroupKFold(n_splits = 10)
    modelo = DecisionTreeClassifier(max_depth=max_depth)
    results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
    train_score = results['train_score'].mean() * 100
    test_score = results['test_score'].mean() * 100
    print("Árvore max_depth = %d, media de treino = %.2f, media de teste = %.2f" % (max_depth,results['train_score'].mean() * 100, results['test_score'].mean() * 100))
    tabela = [max_depth,train_score,test_score]
    return tabela


resultados = [roda_arvore_de_decisao(i) for i in range(1,33)]
resultados = pd.DataFrame(resultados, columns=["max_depth","train", "test"])
# Out:
# Árvore max_depth = 1, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 3, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, media de treino = 78.79, media de teste = 78.63
# Árvore max_depth = 5, media de treino = 78.94, media de teste = 78.56
# Árvore max_depth = 6, media de treino = 79.17, media de teste = 78.12
# Árvore max_depth = 7, media de treino = 79.50, media de teste = 77.96
# Árvore max_depth = 8, media de treino = 79.89, media de teste = 77.86
# Árvore max_depth = 9, media de treino = 80.46, media de teste = 77.38
# Árvore max_depth = 10, media de treino = 81.16, media de teste = 77.19
# Árvore max_depth = 11, media de treino = 82.03, media de teste = 76.97
# Árvore max_depth = 12, media de treino = 82.89, media de teste = 76.49
# Árvore max_depth = 13, media de treino = 83.95, media de teste = 75.81
# Árvore max_depth = 14, media de treino = 85.03, media de teste = 75.66
# Árvore max_depth = 15, media de treino = 86.14, media de teste = 75.16
# Árvore max_depth = 16, media de treino = 87.19, media de teste = 75.11
# Árvore max_depth = 17, media de treino = 88.31, media de teste = 74.74
# Árvore max_depth = 18, media de treino = 89.26, media de teste = 74.33
# Árvore max_depth = 19, media de treino = 90.32, media de teste = 74.34
# Árvore max_depth = 20, media de treino = 91.32, media de teste = 74.22
# Árvore max_depth = 21, media de treino = 92.14, media de teste = 73.80
# Árvore max_depth = 22, media de treino = 93.02, media de teste = 73.81
# Árvore max_depth = 23, media de treino = 93.80, media de teste = 73.38
# Árvore max_depth = 24, media de treino = 94.47, media de teste = 73.43
# Árvore max_depth = 25, media de treino = 95.16, media de teste = 73.14
# Árvore max_depth = 26, media de treino = 95.74, media de teste = 73.04
# Árvore max_depth = 27, media de treino = 96.33, media de teste = 72.91
# Árvore max_depth = 28, media de treino = 96.75, media de teste = 72.66
# Árvore max_depth = 29, media de treino = 97.10, media de teste = 72.73
# Árvore max_depth = 30, media de treino = 97.43, media de teste = 72.81
# Árvore max_depth = 31, media de treino = 97.80, media de teste = 72.86
# Árvore max_depth = 32, media de treino = 98.10, media de teste = 72.52

# %%
resultados.head()
# Out:
#    max_depth      train       test
# 0          1  75.791169  75.784219
# 1          2  75.791169  75.784219
# 2          3  78.750993  78.672633
# 3          4  78.787628  78.632803
# 4          5  78.941007  78.555912

# %% [markdown]
# ## Overfit: ficou "perfeito" para o treino e ruim para o teste.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x = "max_depth", y = "train", data = resultados)
sns.lineplot(x = "max_depth", y = "test", data = resultados)
plt.legend(["Treino","Teste"])

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#    max_depth      train       test
# 2          3  78.750993  78.672633
# 3          4  78.787628  78.632803
# 4          5  78.941007  78.555912
# 5          6  79.170115  78.123266
# 6          7  79.496806  77.963185

# %% [markdown]
# ## Explorando hiperparâmetros em duas dimensões (max_depth e min_samples_leaf)

# %%
def roda_arvore_de_decisao(max_depth,min_samples_leaf):
    SEED = 301
    np.random.seed(SEED)

    cv = GroupKFold(n_splits = 10)
    modelo = DecisionTreeClassifier(max_depth=max_depth,min_samples_leaf=min_samples_leaf)
    results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=True)
    train_score = results['train_score'].mean() * 100
    test_score = results['test_score'].mean() * 100
    print("Árvore max_depth = %d, min_samples_leaf = %d, media de treino = %.2f, media de teste = %.2f" % (max_depth,min_samples_leaf,results['train_score'].mean() * 100, results['test_score'].mean() * 100))
    tabela = [max_depth,min_samples_leaf,train_score,test_score]
    return tabela

def busca():
    resultados = []
    for max_depth in range(1,33):
        for mins_samples_leaf in [32, 64, 128, 256]:
            tabela = roda_arvore_de_decisao(max_depth,mins_samples_leaf)
            resultados.append(tabela)
    resultados = pd.DataFrame(resultados, columns=["max_depth","min_samples_leaf","train", "test"])
    return resultados

resultados = busca()
resultados.head()
# Out:
# Árvore max_depth = 1, min_samples_leaf = 32, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 64, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 128, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 256, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 32, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 64, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 128, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 256, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 3, min_samples_leaf = 32, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 64, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 128, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 256, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 32, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 64, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 128, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 256, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 5, min_samples_leaf = 32, media de treino = 78.82, media de teste = 78.50
# Árvore max_depth = 5, min_samples_leaf = 64, media de treino = 78.79, media de teste = 78.45
# Árvore max_depth = 5, min_samples_leaf = 128, media de treino = 78.77, media de teste = 78.44
# Árvore max_depth = 5, min_samples_leaf = 256, media de treino = 78.77, media de teste = 78.44
# Árvore max_depth = 6, min_samples_leaf = 32, media de treino = 78.96, media de teste = 78.02
# Árvore max_depth = 6, min_samples_leaf = 64, media de treino = 78.92, media de teste = 78.09
# Árvore max_depth = 6, min_samples_leaf = 128, media de treino = 78.85, media de teste = 78.27
# Árvore max_depth = 6, min_samples_leaf = 256, media de treino = 78.79, media de teste = 78.27
# Árvore max_depth = 7, min_samples_leaf = 32, media de treino = 79.24, media de teste = 77.94
# Árvore max_depth = 7, min_samples_leaf = 64, media de treino = 79.18, media de teste = 78.05
# Árvore max_depth = 7, min_samples_leaf = 128, media de treino = 79.01, media de teste = 78.21
# Árvore max_depth = 7, min_samples_leaf = 256, media de treino = 78.85, media de teste = 78.08
# Árvore max_depth = 8, min_samples_leaf = 32, media de treino = 79.47, media de teste = 77.93
# Árvore max_depth = 8, min_samples_leaf = 64, media de treino = 79.30, media de teste = 77.99
# Árvore max_depth = 8, min_samples_leaf = 128, media de treino = 79.05, media de teste = 78.37
# Árvore max_depth = 8, min_samples_leaf = 256, media de treino = 78.89, media de teste = 77.94
# Árvore max_depth = 9, min_samples_leaf = 32, media de treino = 79.80, media de teste = 77.32
# Árvore max_depth = 9, min_samples_leaf = 64, media de treino = 79.46, media de teste = 77.55
# Árvore max_depth = 9, min_samples_leaf = 128, media de treino = 79.12, media de teste = 78.30
# Árvore max_depth = 9, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 10, min_samples_leaf = 32, media de treino = 80.05, media de teste = 77.45
# Árvore max_depth = 10, min_samples_leaf = 64, media de treino = 79.55, media de teste = 77.64
# Árvore max_depth = 10, min_samples_leaf = 128, media de treino = 79.16, media de teste = 78.29
# Árvore max_depth = 10, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 11, min_samples_leaf = 32, media de treino = 80.21, media de teste = 77.20
# Árvore max_depth = 11, min_samples_leaf = 64, media de treino = 79.60, media de teste = 77.53
# Árvore max_depth = 11, min_samples_leaf = 128, media de treino = 79.19, media de teste = 78.31
# Árvore max_depth = 11, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 12, min_samples_leaf = 32, media de treino = 80.34, media de teste = 77.00
# Árvore max_depth = 12, min_samples_leaf = 64, media de treino = 79.72, media de teste = 77.29
# Árvore max_depth = 12, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 12, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 13, min_samples_leaf = 32, media de treino = 80.51, media de teste = 76.85
# Árvore max_depth = 13, min_samples_leaf = 64, media de treino = 79.74, media de teste = 77.34
# Árvore max_depth = 13, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 13, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 14, min_samples_leaf = 32, media de treino = 80.60, media de teste = 76.69
# Árvore max_depth = 14, min_samples_leaf = 64, media de treino = 79.77, media de teste = 77.26
# Árvore max_depth = 14, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 14, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 15, min_samples_leaf = 32, media de treino = 80.70, media de teste = 76.88
# Árvore max_depth = 15, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 15, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 15, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 16, min_samples_leaf = 32, media de treino = 80.76, media de teste = 76.87
# Árvore max_depth = 16, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 16, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 16, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 17, min_samples_leaf = 32, media de treino = 80.82, media de teste = 76.98
# Árvore max_depth = 17, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 17, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 17, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 18, min_samples_leaf = 32, media de treino = 80.85, media de teste = 76.86
# Árvore max_depth = 18, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 18, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 18, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 19, min_samples_leaf = 32, media de treino = 80.86, media de teste = 76.89
# Árvore max_depth = 19, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 19, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 19, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 20, min_samples_leaf = 32, media de treino = 80.88, media de teste = 76.87
# Árvore max_depth = 20, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 20, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 20, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 21, min_samples_leaf = 32, media de treino = 80.88, media de teste = 76.92
# Árvore max_depth = 21, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 21, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 21, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 22, min_samples_leaf = 32, media de treino = 80.88, media de teste = 76.87
# Árvore max_depth = 22, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 22, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 22, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 23, min_samples_leaf = 32, media de treino = 80.88, media de teste = 76.87
# Árvore max_depth = 23, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 23, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 23, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 24, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 24, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 24, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 24, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 25, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 25, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 25, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 25, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 26, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 26, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 26, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 26, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 27, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 27, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 27, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 27, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 28, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 28, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 28, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 28, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 29, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 29, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 29, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 29, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 30, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 30, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 30, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 30, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 31, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 31, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 31, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 31, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 32, min_samples_leaf = 32, media de treino = 80.89, media de teste = 76.84
# Árvore max_depth = 32, min_samples_leaf = 64, media de treino = 79.79, media de teste = 77.30
# Árvore max_depth = 32, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 32, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
#    max_depth  min_samples_leaf      train       test
# 0          1                32  75.791169  75.784219
# 1          1                64  75.791169  75.784219
# 2          1               128  75.791169  75.784219
# 3          1               256  75.791169  75.784219
# 4          2                32  75.791169  75.784219

# %%
resultados.sort_values("test", ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train       test
# 15          4               256  78.750993  78.672633
# 12          4                32  78.750993  78.672633
# 14          4               128  78.750993  78.672633
# 13          4                64  78.750993  78.672633
# 8           3                32  78.750993  78.672633

# %%
corr = resultados.corr()

# %%
sns.heatmap(corr)

# %%
pd.plotting.scatter_matrix(resultados, figsize=(14,8), alpha = 0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A18811B6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1885ACB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1885DB4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A188603DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A18862F780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A18865D128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A188683A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1886AF470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A1886AF4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A188703748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1887320F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1888E6A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A188914400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A18893AD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A188968710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A1889960B8>]],
#       dtype=object)

# %%
sns.pairplot(resultados)

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
def busca():
    resultados = []
    for max_depth in range(1,33):
        for mins_samples_leaf in [128,192,256,512]:
            tabela = roda_arvore_de_decisao(max_depth,mins_samples_leaf)
            resultados.append(tabela)
    resultados = pd.DataFrame(resultados, columns=["max_depth","min_samples_leaf","train", "test"])
    return resultados

resultados = busca()
resultados.head()
# Out:
# Árvore max_depth = 1, min_samples_leaf = 128, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 192, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 256, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 1, min_samples_leaf = 512, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 128, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 192, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 256, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 2, min_samples_leaf = 512, media de treino = 75.79, media de teste = 75.78
# Árvore max_depth = 3, min_samples_leaf = 128, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 192, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 256, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 3, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 4, min_samples_leaf = 128, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 192, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 256, media de treino = 78.75, media de teste = 78.67
# Árvore max_depth = 4, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 5, min_samples_leaf = 128, media de treino = 78.77, media de teste = 78.44
# Árvore max_depth = 5, min_samples_leaf = 192, media de treino = 78.77, media de teste = 78.44
# Árvore max_depth = 5, min_samples_leaf = 256, media de treino = 78.77, media de teste = 78.44
# Árvore max_depth = 5, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 6, min_samples_leaf = 128, media de treino = 78.85, media de teste = 78.27
# Árvore max_depth = 6, min_samples_leaf = 192, media de treino = 78.79, media de teste = 78.31
# Árvore max_depth = 6, min_samples_leaf = 256, media de treino = 78.79, media de teste = 78.27
# Árvore max_depth = 6, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 7, min_samples_leaf = 128, media de treino = 79.01, media de teste = 78.21
# Árvore max_depth = 7, min_samples_leaf = 192, media de treino = 78.92, media de teste = 78.10
# Árvore max_depth = 7, min_samples_leaf = 256, media de treino = 78.85, media de teste = 78.08
# Árvore max_depth = 7, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 8, min_samples_leaf = 128, media de treino = 79.05, media de teste = 78.37
# Árvore max_depth = 8, min_samples_leaf = 192, media de treino = 78.98, media de teste = 78.20
# Árvore max_depth = 8, min_samples_leaf = 256, media de treino = 78.89, media de teste = 77.94
# Árvore max_depth = 8, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 9, min_samples_leaf = 128, media de treino = 79.12, media de teste = 78.30
# Árvore max_depth = 9, min_samples_leaf = 192, media de treino = 78.99, media de teste = 78.11
# Árvore max_depth = 9, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 9, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 10, min_samples_leaf = 128, media de treino = 79.16, media de teste = 78.29
# Árvore max_depth = 10, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 10, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 10, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 11, min_samples_leaf = 128, media de treino = 79.19, media de teste = 78.31
# Árvore max_depth = 11, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 11, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 11, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 12, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 12, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 12, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 12, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 13, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 13, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 13, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 13, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 14, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 14, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 14, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 14, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 15, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 15, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 15, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 15, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 16, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 16, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 16, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 16, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 17, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 17, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 17, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 17, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 18, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 18, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 18, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 18, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 19, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 19, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 19, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 19, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 20, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 20, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 20, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 20, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 21, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 21, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 21, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 21, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 22, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 22, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 22, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 22, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 23, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 23, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 23, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 23, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 24, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 24, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 24, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 24, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 25, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 25, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 25, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 25, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 26, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 26, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 26, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 26, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 27, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 27, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 27, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 27, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 28, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 28, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 28, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 28, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 29, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 29, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 29, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 29, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 30, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 30, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 30, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 30, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 31, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 31, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 31, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 31, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
# Árvore max_depth = 32, min_samples_leaf = 128, media de treino = 79.21, media de teste = 78.22
# Árvore max_depth = 32, min_samples_leaf = 192, media de treino = 79.01, media de teste = 78.05
# Árvore max_depth = 32, min_samples_leaf = 256, media de treino = 78.90, media de teste = 77.85
# Árvore max_depth = 32, min_samples_leaf = 512, media de treino = 77.53, media de teste = 77.50
#    max_depth  min_samples_leaf      train       test
# 0          1               128  75.791169  75.784219
# 1          1               192  75.791169  75.784219
# 2          1               256  75.791169  75.784219
# 3          1               512  75.791169  75.784219
# 4          2               128  75.791169  75.784219

# %%
corr = resultados.corr()

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
resultados.sort_values("test",ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train       test
# 13          4               192  78.750993  78.672633
# 8           3               128  78.750993  78.672633
# 9           3               192  78.750993  78.672633
# 10          3               256  78.750993  78.672633
# 14          4               256  78.750993  78.672633
